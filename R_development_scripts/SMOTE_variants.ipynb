# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import TomekLinks
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import SMOTENC
from imblearn.over_sampling import KMeansSMOTE
from imblearn.combine import SMOTEENN
from imblearn.combine import SMOTETomek
from imblearn.pipeline import Pipeline
import random
from sklearn_extra.cluster import KMedoids
import warnings
import os

# %% [markdown]
# Libraries

# %%
import pandas as pd
import smote_variants as sv

# %%
sv.kmeans_SMOTE()

# %% [markdown]
# Dataset Read

# %%
base_path = "C:/Users/30697/Desktop/PREGSAFE/Data/Folds/"
base_out = "C:/Users/30697/Desktop/PREGSAFE/Data/SMOTE_variants/"
for i in range(1, 11):  # change 6 to however many folds you have + 1
    file_path = f"{base_path}Train_set_{i}.csv"   # like paste("Train_set_", i, ".csv", sep="")
    dataset = pd.read_csv(file_path)
    
    print(i)

    X = dataset.drop(columns=["GDM01"]).to_numpy()     # convert DataFrame → ndarray
    y = dataset["GDM01"].to_numpy().astype(int)



##################################### SMOTE ########################################
    oversampler=sv.distance_SMOTE()
    X_samp,y_samp=oversampler.sample(X,y)

    X_samp_df = pd.DataFrame(X_samp, columns=dataset.drop(columns=["GDM01"]).columns)

# And if you also want y_samp back as a Series:
    y_samp_sr = pd.Series(y_samp, name="GDM01")

# Or combine them into one DataFrame:
    resampled_df = pd.concat([X_samp_df, y_samp_sr], axis=1)


    file_out = f"{base_out}Train_set_{i}_smote.csv"
    resampled_df.to_csv(file_out, index=False)   # row numbers included

    
################################# Bordeline SMOTE ###############################
    oversampler=sv.Borderline_SMOTE1()
    X_samp,y_samp=oversampler.sample(X,y)
    X_samp_df = pd.DataFrame(X_samp, columns=dataset.drop(columns=["GDM01"]).columns)

# And if you also want y_samp back as a Series:
    y_samp_sr = pd.Series(y_samp, name="GDM01")

# Or combine them into one DataFrame:
    resampled_df = pd.concat([X_samp_df, y_samp_sr], axis=1)


    file_out = f"{base_out}Train_set_{i}_borderline_smote.csv"
    resampled_df.to_csv(file_out, index=False)   # row n

    

########################### Kmeans SMOTE ###############################################
    oversampler=sv.kmeans_SMOTE()
    X_samp,y_samp=oversampler.sample(X,y)
    X_samp_df = pd.DataFrame(X_samp, columns=dataset.drop(columns=["GDM01"]).columns)

# And if you also want y_samp back as a Series:
    y_samp_sr = pd.Series(y_samp, name="GDM01")

# Or combine them into one DataFrame:
    resampled_df = pd.concat([X_samp_df, y_samp_sr], axis=1)


    file_out = f"{base_out}Train_set_{i}_kmeans_smote.csv"
    resampled_df.to_csv(file_out, index=False)   # row n


 ############################ SVM SMOTE #################################################
    oversampler=sv.SVM_balance()
    X_samp,y_samp=oversampler.sample(X,y)
    X_samp_df = pd.DataFrame(X_samp, columns=dataset.drop(columns=["GDM01"]).columns)

# And if you also want y_samp back as a Series:
    y_samp_sr = pd.Series(y_samp, name="GDM01")

# Or combine them into one DataFrame:
    resampled_df = pd.concat([X_samp_df, y_samp_sr], axis=1)


    file_out = f"{base_out}Train_set_{i}_svm_smote.csv"
    resampled_df.to_csv(file_out, index=False)   # row n



################################# TOMEK ##################################################
    oversampler=sv.SMOTE_TomekLinks()
    X_samp,y_samp=oversampler.sample(X,y)
    X_samp_df = pd.DataFrame(X_samp, columns=dataset.drop(columns=["GDM01"]).columns)

# And if you also want y_samp back as a Series:
    y_samp_sr = pd.Series(y_samp, name="GDM01")

# Or combine them into one DataFrame:
    resampled_df = pd.concat([X_samp_df, y_samp_sr], axis=1)


    file_out = f"{base_out}Train_set_{i}_tomek_smote.csv"
    resampled_df.to_csv(file_out, index=False)   # row n




######################################## ENN ################################################
    oversampler=sv.SMOTE_ENN()
    X_samp,y_samp=oversampler.sample(X,y)
    X_samp_df = pd.DataFrame(X_samp, columns=dataset.drop(columns=["GDM01"]).columns)

# And if you also want y_samp back as a Series:
    y_samp_sr = pd.Series(y_samp, name="GDM01")

# Or combine them into one DataFrame:
    resampled_df = pd.concat([X_samp_df, y_samp_sr], axis=1)


    file_out = f"{base_out}Train_set_{i}_enn_smote.csv"
    resampled_df.to_csv(file_out, index=False)   # row n
# Out:
# 2025-11-25 14:56:15,710:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'distance_SMOTE'}")
# 2025-11-25 14:56:15,713:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2025-11-25 14:56:15,717:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2025-11-25 14:56:15,723:INFO:distance_SMOTE: simplex sampling with n_dim 2
# 2025-11-25 14:56:15,788:INFO:Borderline_SMOTE1: Running sampling via ('Borderline_SMOTE1', "{'proportion': 1.0, 'n_neighbors': 5, 'k_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Borderline_SMOTE1'}")
# ...

# %%
base_path = "C:/Users/30697/Desktop/PREGSAFE/Data/Folds/"
base_out = "C:/Users/30697/Desktop/PREGSAFE/Data/SMOTE_variants/"
for i in range(1, 11):  # change 6 to however many folds you have + 1
    file_path = f"{base_path}Train_set_{i}.csv"   # like paste("Train_set_", i, ".csv", sep="")
    dataset = pd.read_csv(file_path)
    
    print(i)

    X = dataset.drop(columns=["GDM01"]).to_numpy()     # convert DataFrame → ndarray
    y = dataset["GDM01"].to_numpy().astype(int)




########################### Kmeans SMOTE ###############################################
    oversampler = sv.kmeans_SMOTE(
    proportion = 1.0,          # amount of oversampling (1.0 = fully balance)
    n_neighbors = 5,
    n_clusters = 10,
    irt = 5.0,                 # increase from 2.0 to 5.0 or higher
    random_state = 42
)
    X_samp,y_samp=oversampler.sample(X,y)
    X_samp_df = pd.DataFrame(X_samp, columns=dataset.drop(columns=["GDM01"]).columns)

# And if you also want y_samp back as a Series:
    y_samp_sr = pd.Series(y_samp, name="GDM01")

# Or combine them into one DataFrame:
    resampled_df = pd.concat([X_samp_df, y_samp_sr], axis=1)


    file_out = f"{base_out}Train_set_{i}_kmeans_smote.csv"
    resampled_df.to_csv(file_out, index=False)   # row n


 
######################################## ENN ################################################
    oversampler=oversampler = sv.SMOTE_ENN(
    proportion=0.5,     # bring minority halfway toward balance
    n_neighbors=5,
    random_state=42
)
    X_samp,y_samp=oversampler.sample(X,y)
    X_samp_df = pd.DataFrame(X_samp, columns=dataset.drop(columns=["GDM01"]).columns)

# And if you also want y_samp back as a Series:
    y_samp_sr = pd.Series(y_samp, name="GDM01")

# Or combine them into one DataFrame:
    resampled_df = pd.concat([X_samp_df, y_samp_sr], axis=1)


    file_out = f"{base_out}Train_set_{i}_enn_smote.csv"
    resampled_df.to_csv(file_out, index=False)   # row n
# Out:
# 2025-11-25 15:07:37,937:INFO:kmeans_SMOTE: Running sampling via ('kmeans_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_clusters': 10, 'irt': 5.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': 42, 'class_name': 'kmeans_SMOTE'}")
# 1
# 2025-11-25 15:07:38,191:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2025-11-25 15:07:38,194:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2025-11-25 15:07:38,198:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2025-11-25 15:07:38,200:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2025-11-25 15:07:38,204:INFO:kmeans_SMOTE: simplex sampling with n_dim 2
# 2025-11-25 15:07:38,209:INFO:kmeans_SMOTE: simplex sampling with n_dim 2
# ...
